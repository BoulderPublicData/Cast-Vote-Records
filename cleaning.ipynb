# %%
import pandas as pd
import numpy as np

pd.options.display.max_columns = 300

import matplotlib.pyplot as plt

# %%
df = pd.read_excel('../Data/CVR/2022-CVR.xlsx')
df.head()
# Out:
#   2022 Boulder County General Election     5.13.14.1 Unnamed: 2 Unnamed: 3  \
# 0                                  NaN           NaN        NaN        NaN
# 1                                  NaN           NaN        NaN        NaN
# 2                            CvrNumber  TabulatorNum    BatchId   RecordId
# 3                                    1           103          1         19
# 4                                    2           103          1          8
#
#     Unnamed: 4     Unnamed: 5  Unnamed: 6                          Unnamed: 7  \
# 0          NaN            NaN         NaN  United States Senator (Vote For=1)
# 1          NaN            NaN         NaN                      Michael Bennet
# 2  ImprintedId  CountingGroup  BallotType                                 DEM
# 3     103-1-19        Regular       DS-02                                   1
# 4      103-1-8        Regular       DS-02                                 NaN
#
# ...

# %%
df_clean = df.copy()
df_clean.columns = df_clean.loc[1]
df_clean = df_clean.drop(index=[0,1,2])
df_clean.head()
# Out:
# 1 NaN  NaN NaN NaN       NaN      NaN    NaN Michael Bennet Joe O'Dea  \
# 3   1  103   1  19  103-1-19  Regular  DS-02              1         0
# 4   2  103   1   8   103-1-8  Regular  DS-02            NaN       NaN
# 5   3  103   1  27  103-1-27  Regular  DS-02              0         1
# 6   4  103   1  20  103-1-20  Regular  DS-02            NaN       NaN
# 7   5  103   1   4   103-1-4  Regular  DS-02            NaN       NaN
#
# 1 T.J. Cole Brian Peotter Frank Atwood Write-in John Carleton Rutledge  \
# 3         0             0            0        0                      0
# 4       NaN           NaN          NaN      NaN                    NaN
# 5         0             0            0        0                      0
# 6       NaN           NaN          NaN      NaN                    NaN
# 7       NaN           NaN          NaN      NaN                    NaN
#
# 1 Robert Messman Joanne Rock Tom Harvey Joe Neguse Marshall Dawson  \
# ...
